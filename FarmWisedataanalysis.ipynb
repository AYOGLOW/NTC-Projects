# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cpdata.csv')

# %%
df
# Out:
#       temperature   humidity        ph    rainfall       label
# 0       20.879744  82.002744  6.502985  202.935536        rice
# 1       21.770462  80.319644  7.038096  226.655537        rice
# 2       23.004459  82.320763  7.840207  263.964248        rice
# 3       26.491096  80.158363  6.980401  242.864034        rice
# 4       20.130175  81.604873  7.628473  262.717340        rice
# ...           ...        ...       ...         ...         ...
# 3095    25.287846  89.636679  6.765095   58.286977  watermelon
# 3096    26.638386  84.695469  6.189214   48.324286  watermelon
# 3097    25.331045  84.305338  6.904242   41.532187  watermelon
# 3098    26.897502  83.892415  6.463271   43.971937  watermelon
# 3099    26.986037  89.413849  6.260839   58.548767  watermelon
#
# [3100 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3100 entries, 0 to 3099
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  3100 non-null   float64
#  1   humidity     3100 non-null   float64
#  2   ph           3100 non-null   float64
#  3   rainfall     3100 non-null   float64
#  4   label        3100 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 121.2+ KB

# %%
df.head()
# Out:
#    temperature   humidity        ph    rainfall label
# 0    20.879744  82.002744  6.502985  202.935536  rice
# 1    21.770462  80.319644  7.038096  226.655537  rice
# 2    23.004459  82.320763  7.840207  263.964248  rice
# 3    26.491096  80.158363  6.980401  242.864034  rice
# 4    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#       temperature   humidity        ph   rainfall       label
# 3095    25.287846  89.636679  6.765095  58.286977  watermelon
# 3096    26.638386  84.695469  6.189214  48.324286  watermelon
# 3097    25.331045  84.305338  6.904242  41.532187  watermelon
# 3098    26.897502  83.892415  6.463271  43.971937  watermelon
# 3099    26.986037  89.413849  6.260839  58.548767  watermelon

# %%
df.label.value_counts()
# Out:
# label
# rice            100
# Moth Beans      100
# pomegranate     100
# papaya          100
# orange          100
# muskmelon       100
# mango           100
# apple           100
# grapes          100
# banana          100
# Chickpea        100
# Pigeon Peas     100
# Adzuki Beans    100
# Black gram      100
# Coconut         100
# Kidney Beans    100
# wheat           100
# Tobacco         100
# Sugarcane       100
# Rubber          100
# Peas            100
# Ground Nut      100
# Cotton          100
# Coffee          100
# Jute            100
# Lentil          100
# maize           100
# millet          100
# Tea             100
# Mung Bean       100
# watermelon      100
# Name: count, dtype: int64

# %%
df['label'].nunique()
# Out:
# 31

# %%
df.isnull().sum()
# Out:
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df.describe().T
# Out:
#               count        mean        std        min        25%        50%  \
# temperature  3100.0   27.108466   7.566308   8.825675  22.810495  26.102848
# humidity     3100.0   66.005312  24.007713  10.034048  55.244920  68.980529
# ph           3100.0    6.368913   0.809477   3.504752   5.895343   6.342518
# rainfall     3100.0  110.213031  64.048562  20.211267  64.909095  97.057093
#
#                     75%         max
# temperature   29.365644   54.986760
# humidity      84.446524   99.981876
# ph             6.841616    9.935091
# rainfall     141.210784  397.315380

# %%
sns.kdeplot(data=df, x='temperature')
# Out:
# <Axes: xlabel='temperature', ylabel='Density'>

# %%
sns.histplot(data=df, x='temperature', color='skyblue')
# Out:
# <Axes: xlabel='temperature', ylabel='Count'>

# %%
sns.histplot(data=df, x='humidity', color='salmon')
# Out:
# <Axes: xlabel='humidity', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='humidity')
# Out:
# <Axes: xlabel='humidity', ylabel='Density'>

# %%
sns.histplot(data=df, x='ph', color='plum')
# Out:
# <Axes: xlabel='ph', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='ph')
# Out:
# <Axes: xlabel='ph', ylabel='Density'>

# %%
sns.histplot(data=df, x='rainfall', color='lightgreen')
# Out:
# <Axes: xlabel='rainfall', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='rainfall')
# Out:
# <Axes: xlabel='rainfall', ylabel='Density'>

# %%
sns.boxplot(data=df, x='temperature', color='skyblue')
# Out:
# <Axes: xlabel='temperature'>

# %%
plt.xticks(rotation = 90)
sns.boxplot(data=df, x='label', y='temperature', hue='label').set_title('Temperature by Crop Type')
# Out:
# Text(0.5, 1.0, 'Temperature by Crop Type')

# %%
sns.boxplot(data=df, x='humidity',color='salmon')
# Out:
# <Axes: xlabel='humidity'>

# %%
plt.xticks(rotation = 90)
sns.boxplot(data=df, x='label', y='humidity', hue='label').set_title('Humidity by Crop Type')
# Out:
# Text(0.5, 1.0, 'Humidity by Crop Type')

# %%
sns.boxplot(data=df, x='ph', color='plum')
# Out:
# <Axes: xlabel='ph'>

# %%
plt.xticks(rotation = 90)
sns.boxplot(data=df, x='label', y='ph', hue='label').set_title('pH by Crop Type')
# Out:
# Text(0.5, 1.0, 'pH by Crop Type')

# %%
sns.boxplot(data=df, x='rainfall', color='lightgreen')
# Out:
# <Axes: xlabel='rainfall'>

# %%
plt.xticks(rotation = 90)
sns.boxplot(data=df, x='label', y='rainfall', hue='label').set_title('Rainfall by Crop Type')
# Out:
# Text(0.5, 1.0, 'Rainfall by Crop Type')

# %%
sns.pairplot(df, hue='label')

# %%
num = ['temperature', 'humidity', 'ph', 'rainfall']

# %%
df[num].corr()
# Out:
#              temperature  humidity        ph  rainfall
# temperature     1.000000 -0.076999  0.017024 -0.055143
# humidity       -0.076999  1.000000 -0.002359  0.192074
# ph              0.017024 -0.002359  1.000000 -0.288598
# rainfall       -0.055143  0.192074 -0.288598  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[num].corr(), annot=True)
# Out:
# <Axes: >

# %%
corr = df.corr(numeric_only=True)

# %%
corr
# Out:
#              temperature  humidity        ph  rainfall
# temperature     1.000000 -0.076999  0.017024 -0.055143
# humidity       -0.076999  1.000000 -0.002359  0.192074
# ph              0.017024 -0.002359  1.000000 -0.288598
# rainfall       -0.055143  0.192074 -0.288598  1.000000

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(data=df, x = 'label', y = 'rainfall', color='lightgreen')
# Out:
# <Axes: xlabel='label', ylabel='rainfall'>

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(data=df, x = 'label', y = 'temperature', color='skyblue')
# Out:
# <Axes: xlabel='label', ylabel='temperature'>

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(data=df, x = 'label', y = 'humidity', color='salmon')
# Out:
# <Axes: xlabel='label', ylabel='humidity'>

# %%
plt.figure(figsize=(13,8))
plt.xticks(rotation = 90)
sns.barplot(data=df, x = 'label', y = 'ph', color='plum')
# Out:
# <Axes: xlabel='label', ylabel='ph'>

# %%
ct = pd.crosstab(df['label'],df['temperature'])

# %%
ct
# Out:
# temperature   8.825675   9.467960   9.535586   9.724458   9.851243   \
# label
# Adzuki Beans          0          0          0          0          0
# Black gram            0          0          0          0          0
# Chickpea              0          0          0          0          0
# Coconut               0          0          0          0          0
# Coffee                0          0          0          0          0
# Cotton                0          0          0          0          0
# Ground Nut            0          0          0          0          0
# Jute                  0          0          0          0          0
# Kidney Beans          0          0          0          0          0
# Lentil                0          0          0          0          0
# Moth Beans            0          0          0          0          0
# Mung Bean             0          0          0          0          0
# Peas                  0          0          0          0          0
# ...

# %%
sns.heatmap(data=ct, annot=True, cmap='Greens')
# Out:
# <Axes: xlabel='temperature', ylabel='label'>
